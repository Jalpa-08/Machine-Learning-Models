# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv(r'C:\Users\Jalpa\Desktop\Modular-1\ML_LinearRegression\ML_LinearRegression\DATA\wine_fraud.csv')
df = df1.drop('Unnamed: 0', axis = 1)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality type
# 0      9.4   Legit  red
# 1      9.8   Legit  red
# 2      9.8   Legit  red
# 3      9.8   Legit  red
# 4      9.4   Legit  red

# %%
df
# Out:
#       Unnamed: 0  fixed acidity  volatile acidity  citric acid  \
# 0              0            7.4              0.70         0.00
# 1              1            7.8              0.88         0.00
# 2              2            7.8              0.76         0.04
# 3              3           11.2              0.28         0.56
# 4              4            7.4              0.70         0.00
# ...          ...            ...               ...          ...
# 6492        6492            6.2              0.21         0.29
# 6493        6493            6.6              0.32         0.36
# 6494        6494            6.5              0.24         0.19
# 6495        6495            5.5              0.29         0.30
# 6496        6496            6.0              0.21         0.38
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                1.9      0.076                 11.0                  34.0
# 1                2.6      0.098                 25.0                  67.0
# 2                2.3      0.092                 15.0                  54.0
# 3                1.9      0.075                 17.0                  60.0
# 4                1.9      0.076                 11.0                  34.0
# ...              ...        ...                  ...                   ...
# 6492             1.6      0.039                 24.0                  92.0
# 6493             8.0      0.047                 57.0                 168.0
# 6494             1.2      0.041                 30.0                 111.0
# 6495             1.1      0.022                 20.0                 110.0
# 6496             0.8      0.020                 22.0                  98.0
#
#       density    pH  sulphates  alcohol quality   type
# 0     0.99780  3.51       0.56      9.4   Legit    red
# 1     0.99680  3.20       0.68      9.8   Legit    red
# 2     0.99700  3.26       0.65      9.8   Legit    red
# 3     0.99800  3.16       0.58      9.8   Legit    red
# 4     0.99780  3.51       0.56      9.4   Legit    red
# ...       ...   ...        ...      ...     ...    ...
# 6492  0.99114  3.27       0.50     11.2   Legit  white
# 6493  0.99490  3.15       0.46      9.6   Legit  white
# 6494  0.99254  2.99       0.46      9.4   Legit  white
# 6495  0.98869  3.34       0.38     12.8   Legit  white
# 6496  0.98941  3.26       0.32     11.8   Legit  white
#
# [6497 rows x 14 columns]

# %%
df['quality'].unique()
# Out:
# array(['Legit', 'Fraud'], dtype=object)

# %%
sns.countplot( x= 'quality', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
df['quality'].value_counts()
# Out:
# Legit    6251
# Fraud     246
# Name: quality, dtype: int64

# %%
sns.countplot(x = 'type', data = df, hue = 'quality')
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
reds = df[df['type'] == 'red']
whites = df[df['type'] == 'white']

# %%
reds[reds['quality'] == 'Fraud']
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 18              7.4             0.590         0.08             4.4      0.086
# 38              5.7             1.130         0.09             1.5      0.172
# 41              8.8             0.610         0.30             2.8      0.088
# 45              4.6             0.520         0.15             2.1      0.054
# 73              8.3             0.675         0.26             2.1      0.084
# ...             ...               ...          ...             ...        ...
# 1480            5.6             0.620         0.03             1.5      0.080
# 1482            7.2             0.580         0.54             2.1      0.114
# 1484            6.8             0.910         0.06             2.0      0.060
# 1505            6.7             0.760         0.02             1.8      0.078
# 1521            6.9             0.480         0.20             1.9      0.082
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 18                    6.0                  29.0  0.99740  3.38       0.50
# 38                    7.0                  19.0  0.99400  3.50       0.48
# 41                   17.0                  46.0  0.99760  3.26       0.51
# 45                    8.0                  65.0  0.99340  3.90       0.56
# 73                   11.0                  43.0  0.99760  3.31       0.53
# ...                   ...                   ...      ...   ...        ...
# 1480                  6.0                  13.0  0.99498  3.66       0.62
# 1482                  3.0                   9.0  0.99719  3.33       0.57
# 1484                  4.0                  11.0  0.99592  3.53       0.64
# 1505                  6.0                  12.0  0.99600  3.55       0.63
# 1521                  9.0                  23.0  0.99585  3.39       0.43
#
#       alcohol quality type
# 18       9.00   Fraud  red
# 38       9.80   Fraud  red
# 41       9.30   Fraud  red
# 45      13.10   Fraud  red
# 73       9.20   Fraud  red
# ...       ...     ...  ...
# 1480    10.10   Fraud  red
# 1482    10.30   Fraud  red
# 1484    10.90   Fraud  red
# 1505     9.95   Fraud  red
# 1521     9.05   Fraud  red
#
# [63 rows x 13 columns]

# %%
len(whites[whites['quality'] == 'Fraud'])/len(whites)*100
# Out:
# 3.7362188648427925

# %%
len(reds[reds['quality'] == 'Fraud'])/len(reds)*100
# Out:
# 3.9399624765478425

# %%
df['fraud'] = df['quality'].map({'Legit': 0, 'Fraud' : 1})

# %%
#Correlation with respect to varour features
df.corr()['fraud']
# Out:
# fixed acidity           0.021794
# volatile acidity        0.151228
# citric acid            -0.061789
# residual sugar         -0.048756
# chlorides               0.034499
# free sulfur dioxide    -0.085204
# total sulfur dioxide   -0.035252
# density                 0.016351
# pH                      0.020107
# sulphates              -0.034046
# alcohol                -0.051141
# fraud                   1.000000
# Name: fraud, dtype: float64

# %%
df.corr()['fraud'][: -1].sort_values() #correlations of frauf wrt various features
# Out:
# free sulfur dioxide    -0.085204
# citric acid            -0.061789
# alcohol                -0.051141
# residual sugar         -0.048756
# total sulfur dioxide   -0.035252
# sulphates              -0.034046
# density                 0.016351
# pH                      0.020107
# fixed acidity           0.021794
# chlorides               0.034499
# volatile acidity        0.151228
# Name: fraud, dtype: float64

# %%
plt.figure(dpi =150)
df.corr()['fraud'][: -1].sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(11,8),dpi =150)
sns.heatmap(df.corr(), cmap = 'viridis', annot = True)
# Out:
# <AxesSubplot:>

# %%
df = df.drop('fraud', axis = 1)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol quality   type
# 0         9.4   Legit    red
# 1         9.8   Legit    red
# 2         9.8   Legit    red
# 3         9.8   Legit    red
# 4         9.4   Legit    red
# ...       ...     ...    ...
# 6492     11.2   Legit  white
# 6493      9.6   Legit  white
# 6494      9.4   Legit  white
# 6495     12.8   Legit  white
# 6496     11.8   Legit  white
#
# [6497 rows x 13 columns]

# %%
# Feature Encoding
df['type'] = pd.get_dummies(df['type'], drop_first = True)

# %%
X = df.drop('quality', axis =1)

# %%
y = df['quality']

# %%
from sklearn.model_selection import train_test_split

# %%
df.shape
# Out:
# (6497, 13)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.1, random_state = 101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_X_train = scaler.fit_transform(X_train)

# %%
scaled_X_test = scaler.transform(X_test)

# %%
from sklearn.svm import SVC

# %%
svc = SVC(class_weight = 'balanced')

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C': [0.001, 0.01, 0.1, 0.5,1]}

# %%
grid_model =GridSearchCV(svc, param_grid)

# %%
grid_model.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(class_weight='balanced'),
#              param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1]})

# %%
grid_model.best_params_
# Out:
# {'C': 1}

# %%
from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix

# %%
grid_preds = grid_model.predict(scaled_X_test)

# %%
confusion_matrix(y_test, grid_preds)
# Out:
# array([[ 17,  10],
#        [ 92, 531]], dtype=int64)

# %%
plot_confusion_matrix(grid_model, scaled_X_test, y_test)
# Out:
# C:\Users\Jalpa\anaconda3\envs\mlclass\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(classification_report(y_test, grid_preds))
# Out:
#               precision    recall  f1-score   support
#
#        Fraud       0.16      0.63      0.25        27
#        Legit       0.98      0.85      0.91       623
#
#     accuracy                           0.84       650
#    macro avg       0.57      0.74      0.58       650
# weighted avg       0.95      0.84      0.88       650
